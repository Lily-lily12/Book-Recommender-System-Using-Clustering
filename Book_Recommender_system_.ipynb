# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
book = pd.read_csv('Books.csv')
user = pd.read_csv('Users.csv')
rating = pd.read_csv('Ratings.csv')

# %%
book.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 163834 entries, 0 to 163833
# Data columns (total 8 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   ISBN                 163834 non-null  object
#  1   Book-Title           163834 non-null  object
#  2   Book-Author          163833 non-null  object
#  3   Year-Of-Publication  163834 non-null  int64
#  4   Publisher            163832 non-null  object
#  5   Image-URL-S          163834 non-null  object
#  6   Image-URL-M          163833 non-null  object
#  7   Image-URL-L          163833 non-null  object
# dtypes: int64(1), object(7)
# memory usage: 10.0+ MB

# %%
rating.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1149780 entries, 0 to 1149779
# Data columns (total 3 columns):
#  #   Column       Non-Null Count    Dtype
# ---  ------       --------------    -----
#  0   User-ID      1149780 non-null  int64
#  1   ISBN         1149780 non-null  object
#  2   Book-Rating  1149780 non-null  int64
# dtypes: int64(2), object(1)
# memory usage: 26.3+ MB

# %%
user.head()
# Out:
#    User-ID                            Location   Age
# 0        1                  nyc, new york, usa   NaN
# 1        2           stockton, california, usa  18.0
# 2        3     moscow, yukon territory, russia   NaN
# 3        4           porto, v.n.gaia, portugal  17.0
# 4        5  farnborough, hants, united kingdom   NaN

# %%
book.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author  Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                 2002     Oxford University Press
# 1  Richard Bruce Wright                 2001       HarperFlamingo Canada
# 2          Carlo D'Este                 1991             HarperPerennial
# 3      Gina Bari Kolata                 1999        Farrar Straus Giroux
# 4       E. J. W. Barber                 1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...
# 1  http://images.amazon.com/images/P/0002005018.0...
# 2  http://images.amazon.com/images/P/0060973129.0...
# 3  http://images.amazon.com/images/P/0374157065.0...
# 4  http://images.amazon.com/images/P/0393045218.0...

# %%
rating.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
#Check for missing values
book.isnull().sum()
# Out:
# ISBN                   0
# Book-Title             0
# Book-Author            1
# Year-Of-Publication    0
# Publisher              2
# Image-URL-S            0
# Image-URL-M            1
# Image-URL-L            1
# dtype: int64

# %%
user.isnull().sum()
# Out:
# User-ID          0
# Location         0
# Age         110762
# dtype: int64

# %%
rating.isnull().sum()
# Out:
# User-ID        0
# ISBN           0
# Book-Rating    0
# dtype: int64

# %%
ratings_with_name = rating.merge(book,on='ISBN')
ratings_with_name
# Out:
#         User-ID        ISBN  Book-Rating  \
# 0        276725  034545104X            0
# 1          2313  034545104X            5
# 2          6543  034545104X            0
# 3          8680  034545104X            5
# 4         10314  034545104X            9
# ...         ...         ...          ...
# 891323   276688  0517145553            0
# 891324   276688  1575660792            7
# 891325   276690  0590907301            0
# 891326   276704  0679752714            0
# 891327   276704  0806917695            5
#
#                                                Book-Title      Book-Author  \
# 0                                    Flesh Tones: A Novel       M. J. Rose
# 1                                    Flesh Tones: A Novel       M. J. Rose
# 2                                    Flesh Tones: A Novel       M. J. Rose
# 3                                    Flesh Tones: A Novel       M. J. Rose
# 4                                    Flesh Tones: A Novel       M. J. Rose
# ...                                                   ...              ...
# 891323                                    Mostly Harmless    Douglas Adams
# 891324                                        Gray Matter  Shirley Kennett
# 891325  Triplet Trouble and the Class Trip (Triplet Tr...     Debbie Dadey
# 891326  A Desert of Pure Feeling (Vintage Contemporaries)   Judith Freeman
# 891327  Perplexing Lateral Thinking Puzzles: Scholasti...      Paul Sloane
#
#         Year-Of-Publication                          Publisher  \
# 0                      2002                   Ballantine Books
# 1                      2002                   Ballantine Books
# 2                      2002                   Ballantine Books
# 3                      2002                   Ballantine Books
# 4                      2002                   Ballantine Books
# ...                     ...                                ...
# 891323                 1995             Random House Value Pub
# 891324                 1996  Kensington Publishing Corporation
# 891325                 1997                              Apple
# 891326                 1997                  Vintage Books USA
# 891327                 1997                Sterling Publishing
#
#                                               Image-URL-S  \
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/034545104X.0...
# 2       http://images.amazon.com/images/P/034545104X.0...
# 3       http://images.amazon.com/images/P/034545104X.0...
# 4       http://images.amazon.com/images/P/034545104X.0...
# ...                                                   ...
# 891323  http://images.amazon.com/images/P/0517145553.0...
# 891324  http://images.amazon.com/images/P/1575660792.0...
# 891325  http://images.amazon.com/images/P/0590907301.0...
# 891326  http://images.amazon.com/images/P/0679752714.0...
# 891327  http://images.amazon.com/images/P/0806917695.0...
#
#                                               Image-URL-M  \
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/034545104X.0...
# 2       http://images.amazon.com/images/P/034545104X.0...
# 3       http://images.amazon.com/images/P/034545104X.0...
# 4       http://images.amazon.com/images/P/034545104X.0...
# ...                                                   ...
# 891323  http://images.amazon.com/images/P/0517145553.0...
# 891324  http://images.amazon.com/images/P/1575660792.0...
# 891325  http://images.amazon.com/images/P/0590907301.0...
# 891326  http://images.amazon.com/images/P/0679752714.0...
# 891327  http://images.amazon.com/images/P/0806917695.0...
#
#                                               Image-URL-L
# 0       http://images.amazon.com/images/P/034545104X.0...
# 1       http://images.amazon.com/images/P/034545104X.0...
# 2       http://images.amazon.com/images/P/034545104X.0...
# 3       http://images.amazon.com/images/P/034545104X.0...
# 4       http://images.amazon.com/images/P/034545104X.0...
# ...                                                   ...
# 891323  http://images.amazon.com/images/P/0517145553.0...
# 891324  http://images.amazon.com/images/P/1575660792.0...
# 891325  http://images.amazon.com/images/P/0590907301.0...
# 891326  http://images.amazon.com/images/P/0679752714.0...
# 891327  http://images.amazon.com/images/P/0806917695.0...
#
# [891328 rows x 10 columns]

# %%
num_rating_df = ratings_with_name.groupby('Book-Title').count()['Book-Rating'].reset_index()
num_rating_df.rename(columns={'Book-Rating':'num_ratings'},inplace=True)
num_rating_df
# Out:
#                                                Book-Title  num_ratings
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                    Apple Magic (The Collector's series)            1
# 2        Beyond IBM: Leadership Marketing and Finance ...            1
# 3                                            Dark Justice            1
# 4        Earth Prayers From around the World: 365 Pray...           10
# ...                                                   ...          ...
# 147435                                     Ã?Â?bermorgen.            1
# 147436                                      Ã?Â?lpiraten.            2
# 147437                     Ã?Â?rger mit Produkt X. Roman.            4
# 147438                              Ã?Â?stlich der Berge.            3
# 147439                                  Ã?Â?thique en toc            2
#
# [147440 rows x 2 columns]

# %%
# Group by 'Book-Title' and calculate the mean of 'Book-Rating'
avg_rating_df = ratings_with_name.groupby('Book-Title')['Book-Rating'].mean().reset_index()
avg_rating_df.rename(columns={'Book-Rating':'avg_ratings'},inplace=True)

# %%
avg_rating_df
# Out:
#                                                Book-Title  avg_ratings
# 0        A Light in the Storm: The Civil War Diary of ...     2.250000
# 1                    Apple Magic (The Collector's series)     0.000000
# 2        Beyond IBM: Leadership Marketing and Finance ...     0.000000
# 3                                            Dark Justice    10.000000
# 4        Earth Prayers From around the World: 365 Pray...     5.000000
# ...                                                   ...          ...
# 147435                                     Ã?Â?bermorgen.     0.000000
# 147436                                      Ã?Â?lpiraten.     0.000000
# 147437                     Ã?Â?rger mit Produkt X. Roman.     5.250000
# 147438                              Ã?Â?stlich der Berge.     2.666667
# 147439                                  Ã?Â?thique en toc     4.000000
#
# [147440 rows x 2 columns]

# %%
popular_df = num_rating_df.merge(avg_rating_df,on='Book-Title')
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 0        A Light in the Storm: The Civil War Diary of ...            4
# 1                    Apple Magic (The Collector's series)            1
# 2        Beyond IBM: Leadership Marketing and Finance ...            1
# 3                                            Dark Justice            1
# 4        Earth Prayers From around the World: 365 Pray...           10
# ...                                                   ...          ...
# 147435                                     Ã?Â?bermorgen.            1
# 147436                                      Ã?Â?lpiraten.            2
# 147437                     Ã?Â?rger mit Produkt X. Roman.            4
# 147438                              Ã?Â?stlich der Berge.            3
# 147439                                  Ã?Â?thique en toc            2
#
#         avg_ratings
# 0          2.250000
# 1          0.000000
# 2          0.000000
# 3         10.000000
# 4          5.000000
# ...             ...
# 147435     0.000000
# 147436     0.000000
# 147437     5.250000
# 147438     2.666667
# 147439     4.000000
#
# [147440 rows x 3 columns]

# %% [markdown]
# This part filters the DataFrame popular_df to include only rows where the value in the 'num_ratings' column is greater than or equal to 250. It's selecting only those books that have received at least 250 ratings.

# %%
popular_df = popular_df[popular_df['num_ratings']>=250].sort_values('avg_ratings',ascending=False).head(50)

# %%
popular_df
# Out:
#                                                Book-Title  num_ratings  \
# 48917   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 48908        Harry Potter and the Goblet of Fire (Book 4)          387
# 48923      Harry Potter and the Sorcerer's Stone (Book 1)          274
# 48911   Harry Potter and the Order of the Phoenix (Boo...          346
# 48900    Harry Potter and the Chamber of Secrets (Book 2)          556
# 116920  The Hobbit : The Enchanting Prelude to The Lor...          281
# 114178  The Fellowship of the Ring (The Lord of the Ri...          368
# 48926   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 129533     The Two Towers (The Lord of the Rings, Part 2)          258
# 134457                              To Kill a Mockingbird          506
# 111726                                  The Da Vinci Code          894
# 114511                 The Five People You Meet in Heaven          427
# 109858                             The Catcher in the Rye          448
# 450                                                  1984          283
# 120025                          The Lovely Bones: A Novel         1295
# 87499                            Prodigal Summer: A Novel          253
# 78128                                          Neverwhere          265
# 126415                            The Secret Life of Bees          773
# 136531  Tuesdays with Morrie: An Old Man, a Young Man,...          492
# 102567  Stupid White Men ...and Other Sorry Excuses fo...          283
# 125066                The Red Tent (Bestselling Backlist)          723
# 116903               The Hitchhiker's Guide to the Galaxy          266
# 78534    Nickel and Dimed: On (Not) Getting By in America          335
# 56796                                       Into the Wild          252
# 38896                                      Fahrenheit 451          406
# 45439                           Girl with a Pearl Earring          526
# 82708                                           Outlander          280
# 142794  Where the Heart Is (Oprah's Book Club (Paperba...          585
# 94723                      Seabiscuit: An American Legend          275
# 65505                                          Life of Pi          664
# 107474                                     The Bean Trees          389
# 1363    A Child Called \It\": One Child's Courage to S...          265
# 5196                                       ANGELA'S ASHES          279
# 46410                                         Good in Bed          490
# 115596    The Golden Compass (His Dark Materials, Book 1)          332
# 39547   Fast Food Nation: The Dark Side of the All-Ame...          321
# 98186                                  Skipping Christmas          321
# 7790                                        American Gods          302
# 64193   Left Behind: A Novel of the Earth's Last Days ...          318
# 110576                                   The Color Purple          314
# 97358                                Silence of the Lambs          255
# 5385                                          About a Boy          262
# 95972                   Seven Up (A Stephanie Plum Novel)          278
# 106434  The Alchemist: A Fable About Following Your Dream          266
# 103409                       Suzanne's Diary for Nicholas          455
# 67351                                   Lord of the Flies          257
# 48682   Hard Eight : A Stephanie Plum Novel (A Stephan...          268
# 3515                              A Prayer for Owen Meany          413
# 129942   The Vampire Lestat (Vampire Chronicles, Book II)          301
# 143096       White Oleander : A Novel (Oprah's Book Club)          356
#
#         avg_ratings
# 48917      5.852804
# 48908      5.824289
# 48923      5.748175
# 48911      5.488439
# 48900      5.183453
# 116920     5.007117
# 114178     4.948370
# 48926      4.895652
# 129533     4.841085
# 134457     4.687747
# 111726     4.652125
# 114511     4.543326
# 109858     4.537946
# 450        4.469965
# 120025     4.468726
# 87499      4.450593
# 78128      4.449057
# 126415     4.439845
# 136531     4.363821
# 102567     4.356890
# 125066     4.334716
# 116903     4.327068
# 78534      4.289552
# 56796      4.273810
# 38896      4.248768
# 45439      4.218631
# 82708      4.160714
# 142794     4.105983
# 94723      4.098182
# 65505      4.088855
# 107474     4.087404
# 1363       4.086792
# 5196       4.075269
# 46410      4.055102
# 115596     4.048193
# 39547      4.037383
# 98186      4.018692
# 7790       4.006623
# 64193      4.003145
# 110576     3.964968
# 97358      3.937255
# 5385       3.900763
# 95972      3.888489
# 106434     3.875940
# 103409     3.837363
# 67351      3.813230
# 48682      3.809701
# 3515       3.796610
# 129942     3.777409
# 143096     3.772472

# %% [markdown]
# # USING K-MEANS CLUSTERING

# %%
X=popular_df[[	'num_ratings',	'avg_ratings']]

# %%
X
# Out:
#         num_ratings  avg_ratings
# 48917           428     5.852804
# 48908           387     5.824289
# 48923           274     5.748175
# 48911           346     5.488439
# 48900           556     5.183453
# 116920          281     5.007117
# 114178          368     4.948370
# 48926           575     4.895652
# 129533          258     4.841085
# 134457          506     4.687747
# 111726          894     4.652125
# 114511          427     4.543326
# 109858          448     4.537946
# 450             283     4.469965
# 120025         1295     4.468726
# 87499           253     4.450593
# 78128           265     4.449057
# 126415          773     4.439845
# 136531          492     4.363821
# 102567          283     4.356890
# 125066          723     4.334716
# 116903          266     4.327068
# 78534           335     4.289552
# 56796           252     4.273810
# 38896           406     4.248768
# 45439           526     4.218631
# 82708           280     4.160714
# 142794          585     4.105983
# 94723           275     4.098182
# 65505           664     4.088855
# 107474          389     4.087404
# 1363            265     4.086792
# 5196            279     4.075269
# 46410           490     4.055102
# 115596          332     4.048193
# 39547           321     4.037383
# 98186           321     4.018692
# 7790            302     4.006623
# 64193           318     4.003145
# 110576          314     3.964968
# 97358           255     3.937255
# 5385            262     3.900763
# 95972           278     3.888489
# 106434          266     3.875940
# 103409          455     3.837363
# 67351           257     3.813230
# 48682           268     3.809701
# 3515            413     3.796610
# 129942          301     3.777409
# 143096          356     3.772472

# %%
# Normalization
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled_features = scaler.fit_transform(X)

# %%
from sklearn.cluster import KMeans
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters = i, init = 'k-means++', random_state = 42)
    kmeans.fit(scaled_features)
    wcss.append(kmeans.inertia_)
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
kmeans = KMeans(n_clusters = 4, init = 'k-means++', random_state = 42)
popular_df['Cluster'] = kmeans.fit_predict(scaled_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
popular_df.head(10)
# Out:
#                                                Book-Title  num_ratings  \
# 48917   Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 48908        Harry Potter and the Goblet of Fire (Book 4)          387
# 48923      Harry Potter and the Sorcerer's Stone (Book 1)          274
# 48911   Harry Potter and the Order of the Phoenix (Boo...          346
# 48900    Harry Potter and the Chamber of Secrets (Book 2)          556
# 116920  The Hobbit : The Enchanting Prelude to The Lor...          281
# 114178  The Fellowship of the Ring (The Lord of the Ri...          368
# 48926   Harry Potter and the Sorcerer's Stone (Harry P...          575
# 129533     The Two Towers (The Lord of the Rings, Part 2)          258
# 134457                              To Kill a Mockingbird          506
#
#         avg_ratings  Cluster
# 48917      5.852804        1
# 48908      5.824289        1
# 48923      5.748175        1
# 48911      5.488439        1
# 48900      5.183453        1
# 116920     5.007117        1
# 114178     4.948370        1
# 48926      4.895652        0
# 129533     4.841085        1
# 134457     4.687747        0

# %%
def recommend_books(book_title, popular_df):
    cluster = popular_df[popular_df['Book-Title'] == book_title]['Cluster'].values[0]
    recommended_books = popular_df[popular_df['Cluster'] == cluster]['Book-Title'].values
    return recommended_books

# %%
print(recommend_books("To Kill a Mockingbird", popular_df))
# Out:
# ["Harry Potter and the Sorcerer's Stone (Harry Potter (Paperback))"
#  'To Kill a Mockingbird' 'The Five People You Meet in Heaven'
#  'The Catcher in the Rye'
#  "Tuesdays with Morrie: An Old Man, a Young Man, and Life's Greatest Lesson"
#  'The Red Tent (Bestselling Backlist)' 'Girl with a Pearl Earring'
#  "Where the Heart Is (Oprah's Book Club (Paperback))" 'Life of Pi'
#  'Good in Bed']

# %% [markdown]
# # Using Hierarchial Clustering

# %%
scaled_features
# Out:
# array([[ 1.29009011e-01,  2.82527872e+00],
#        [-8.18908875e-02,  2.77120494e+00],
#        [-6.63151584e-01,  2.62686405e+00],
#        [-2.92790786e-01,  2.13430821e+00],
#        [ 7.87428207e-01,  1.55594116e+00],
#        [-6.27144284e-01,  1.22154289e+00],
#        [-1.79624987e-01,  1.11013507e+00],
#        [ 8.85162307e-01,  1.01016328e+00],
#        [-7.45453983e-01,  9.06684136e-01],
#        [ 5.30233209e-01,  6.15897797e-01],
#        [ 2.52606640e+00,  5.48345696e-01],
#        [ 1.23865111e-01,  3.42020891e-01],
#        [ 2.31887011e-01,  3.31820119e-01],
#        [-6.16856484e-01,  2.02901404e-01],
#        [ 4.58877028e+00,  2.00552187e-01],
#        [-7.71173483e-01,  1.66165305e-01],
#        [-7.09446684e-01,  1.63251943e-01],
#        [ 1.90365450e+00,  1.45782862e-01],
#        [ 4.58218609e-01,  1.61379201e-03],
#        [-6.16856484e-01, -1.15293534e-02],
#        [ 1.64645950e+00, -5.35795067e-02],
#        [-7.04302784e-01, -6.80844580e-02],
#        [-3.49373686e-01, -1.39227670e-01],
#        [-7.76317383e-01, -1.69081714e-01],
#        [ 1.58432119e-02, -2.16568862e-01],
#        [ 6.33111208e-01, -2.73720383e-01],
#        [-6.32288184e-01, -3.83552358e-01],
#        [ 9.36601306e-01, -4.87343415e-01],
#        [-6.58007684e-01, -5.02137180e-01],
#        [ 1.34296940e+00, -5.19823497e-01],
#        [-7.16030876e-02, -5.22576693e-01],
#        [-7.09446684e-01, -5.23735653e-01],
#        [-6.37432084e-01, -5.45588753e-01],
#        [ 4.47930809e-01, -5.83832464e-01],
#        [-3.64805386e-01, -5.96935009e-01],
#        [-4.21388285e-01, -6.17434020e-01],
#        [-4.21388285e-01, -6.52880226e-01],
#        [-5.19122385e-01, -6.75767676e-01],
#        [-4.36819985e-01, -6.82362997e-01],
#        [-4.57395585e-01, -7.54759846e-01],
#        [-7.60885683e-01, -8.07314479e-01],
#        [-7.24878384e-01, -8.76516020e-01],
#        [-6.42575984e-01, -8.99792375e-01],
#        [-7.04302784e-01, -9.23590628e-01],
#        [ 2.67894310e-01, -9.96747374e-01],
#        [-7.50597883e-01, -1.04251264e+00],
#        [-6.94014984e-01, -1.04920319e+00],
#        [ 5.18505117e-02, -1.07402921e+00],
#        [-5.24266285e-01, -1.11044246e+00],
#        [-2.41351787e-01, -1.11980433e+00]])

# %%
import scipy.cluster.hierarchy as sch
dendrogram = sch.dendrogram(sch.linkage(scaled_features, method = 'ward'))
plt.title('Dendrogram')
plt.xlabel('books')
plt.ylabel('Euclidean distances')
plt.show()

# %%
df_copy = popular_df.copy()

# %%
df_copy = df_copy.drop(columns=['Cluster'])
df_copy.head()
# Out:
#                                               Book-Title  num_ratings  \
# 48917  Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 48908       Harry Potter and the Goblet of Fire (Book 4)          387
# 48923     Harry Potter and the Sorcerer's Stone (Book 1)          274
# 48911  Harry Potter and the Order of the Phoenix (Boo...          346
# 48900   Harry Potter and the Chamber of Secrets (Book 2)          556
#
#        avg_ratings
# 48917     5.852804
# 48908     5.824289
# 48923     5.748175
# 48911     5.488439
# 48900     5.183453

# %%
from sklearn.cluster import AgglomerativeClustering
hc = AgglomerativeClustering(n_clusters = 2, affinity = 'euclidean', linkage = 'ward')
y_hc = hc.fit_predict(scaled_features)
df_copy['Cluster'] = kmeans.fit_predict(scaled_features)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_agglomerative.py:983: FutureWarning: Attribute `affinity` was deprecated in version 1.2 and will be removed in 1.4. Use `metric` instead
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/cluster/_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df_copy.head()
# Out:
#                                               Book-Title  num_ratings  \
# 48917  Harry Potter and the Prisoner of Azkaban (Book 3)          428
# 48908       Harry Potter and the Goblet of Fire (Book 4)          387
# 48923     Harry Potter and the Sorcerer's Stone (Book 1)          274
# 48911  Harry Potter and the Order of the Phoenix (Boo...          346
# 48900   Harry Potter and the Chamber of Secrets (Book 2)          556
#
#        avg_ratings  Cluster
# 48917     5.852804        1
# 48908     5.824289        1
# 48923     5.748175        1
# 48911     5.488439        1
# 48900     5.183453        1

# %%
def recommend_books(book_title, df_copy):
    cluster = df_copy[df_copy['Book-Title'] == book_title]['Cluster'].values[0]
    recommended_books = df_copy[df_copy['Cluster'] == cluster]['Book-Title'].values
    return recommended_books

# %%
recommend_books('1984',df_copy)
# Out:
# array(['1984', 'Prodigal Summer: A Novel', 'Neverwhere',
#        'Stupid White Men ...and Other Sorry Excuses for the State of the Nation!',
#        "The Hitchhiker's Guide to the Galaxy",
#        'Nickel and Dimed: On (Not) Getting By in America',
#        'Into the Wild', 'Fahrenheit 451', 'Outlander',
#        'Seabiscuit: An American Legend', 'The Bean Trees',
#        'A Child Called \\It\\": One Child\'s Courage to Survive"',
#        "ANGELA'S ASHES",
#        'The Golden Compass (His Dark Materials, Book 1)',
#        'Fast Food Nation: The Dark Side of the All-American Meal',
#        'Skipping Christmas', 'American Gods',
#        "Left Behind: A Novel of the Earth's Last Days (Left Behind No. 1)",
#        'The Color Purple', 'Silence of the Lambs', 'About a Boy',
#        'Seven Up (A Stephanie Plum Novel)',
#        'The Alchemist: A Fable About Following Your Dream',
#        "Suzanne's Diary for Nicholas", 'Lord of the Flies',
#        'Hard Eight : A Stephanie Plum Novel (A Stephanie Plum Novel)',
#        'A Prayer for Owen Meany',
#        'The Vampire Lestat (Vampire Chronicles, Book II)',
#        "White Oleander : A Novel (Oprah's Book Club)"], dtype=object)
